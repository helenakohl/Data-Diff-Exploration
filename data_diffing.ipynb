# %%
import sqlite3
import pandas as pd

# %%
# Connect to the SQLite databases
conn1 = sqlite3.connect('songs1.sqlite')
conn2 = sqlite3.connect('songs2.sqlite')
conn3 = sqlite3.connect('songs3.sqlite')
conn4 = sqlite3.connect('songs4.sqlite')
conn5 = sqlite3.connect('songs5.sqlite')

# Load tables into pandas DataFrames
table_v1 = pd.read_sql_query("SELECT * FROM songs", conn1)
table_v2 = pd.read_sql_query("SELECT * FROM songs", conn2)
table_v3 = pd.read_sql_query("SELECT * FROM songs", conn3)
table_v4 = pd.read_sql_query("SELECT * FROM songs", conn4)
table_v5 = pd.read_sql_query("SELECT * FROM songs", conn5)

# %% [markdown]
# Column comparison

# %%
# find deleted columns
missing_cols = [column for column in table_v1.columns if column not in table_v2.columns]

# find added columns
added_cols = [column for column in table_v2.columns if column not in table_v1.columns]

# find common columns 
common_cols = [column for column in table_v1.columns if column in table_v2.columns]

print('common: ', common_cols)
print('added: ', added_cols)
print('removed: ', missing_cols)
# Out:
# common:  ['artist_names', 'track_name', 'source', 'tempo', 'weeks_on_chart', 'streams']
# added:  ['mode', 'loudness']
# removed:  ['id', 'duration_ms']

# %%
# combine versions to also display deleted rows 
comparison = pd.merge(table_v1, table_v2, on = common_cols, how= 'outer')

# %%
def apply_color(col, color):
    return [f'background-color: {color}' for c in col]

styled_df = comparison.head(20).style.apply(apply_color, color='red', subset=pd.IndexSlice[:, missing_cols])\
                     .apply(apply_color, color='green', subset=pd.IndexSlice[:, added_cols])

# %% [markdown]
# Highlight added cloumns green and deleted ones red

# %%
styled_df
# Out:
# <style type="text/css">
# #T_e82d5_row0_col0, #T_e82d5_row0_col5, #T_e82d5_row1_col0, #T_e82d5_row1_col5, #T_e82d5_row2_col0, #T_e82d5_row2_col5, #T_e82d5_row3_col0, #T_e82d5_row3_col5, #T_e82d5_row4_col0, #T_e82d5_row4_col5, #T_e82d5_row5_col0, #T_e82d5_row5_col5, #T_e82d5_row6_col0, #T_e82d5_row6_col5, #T_e82d5_row7_col0, #T_e82d5_row7_col5, #T_e82d5_row8_col0, #T_e82d5_row8_col5, #T_e82d5_row9_col0, #T_e82d5_row9_col5, #T_e82d5_row10_col0, #T_e82d5_row10_col5, #T_e82d5_row11_col0, #T_e82d5_row11_col5, #T_e82d5_row12_col0, #T_e82d5_row12_col5, #T_e82d5_row13_col0, #T_e82d5_row13_col5, #T_e82d5_row14_col0, #T_e82d5_row14_col5, #T_e82d5_row15_col0, #T_e82d5_row15_col5, #T_e82d5_row16_col0, #T_e82d5_row16_col5, #T_e82d5_row17_col0, #T_e82d5_row17_col5, #T_e82d5_row18_col0, #T_e82d5_row18_col5, #T_e82d5_row19_col0, #T_e82d5_row19_col5 {
#   background-color: red;
# }
# #T_e82d5_row0_col8, #T_e82d5_row0_col9, #T_e82d5_row1_col8, #T_e82d5_row1_col9, #T_e82d5_row2_col8, #T_e82d5_row2_col9, #T_e82d5_row3_col8, #T_e82d5_row3_col9, #T_e82d5_row4_col8, #T_e82d5_row4_col9, #T_e82d5_row5_col8, #T_e82d5_row5_col9, #T_e82d5_row6_col8, #T_e82d5_row6_col9, #T_e82d5_row7_col8, #T_e82d5_row7_col9, #T_e82d5_row8_col8, #T_e82d5_row8_col9, #T_e82d5_row9_col8, #T_e82d5_row9_col9, #T_e82d5_row10_col8, #T_e82d5_row10_col9, #T_e82d5_row11_col8, #T_e82d5_row11_col9, #T_e82d5_row12_col8, #T_e82d5_row12_col9, #T_e82d5_row13_col8, #T_e82d5_row13_col9, #T_e82d5_row14_col8, #T_e82d5_row14_col9, #T_e82d5_row15_col8, #T_e82d5_row15_col9, #T_e82d5_row16_col8, #T_e82d5_row16_col9, #T_e82d5_row17_col8, #T_e82d5_row17_col9, #T_e82d5_row18_col8, #T_e82d5_row18_col9, #T_e82d5_row19_col8, #T_e82d5_row19_col9 {
#   background-color: green;
# }
# </style>
# <table id="T_e82d5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e82d5_level0_col0" class="col_heading level0 col0" >id</th>
#       <th id="T_e82d5_level0_col1" class="col_heading level0 col1" >artist_names</th>
#       <th id="T_e82d5_level0_col2" class="col_heading level0 col2" >track_name</th>
#       <th id="T_e82d5_level0_col3" class="col_heading level0 col3" >source</th>
#       <th id="T_e82d5_level0_col4" class="col_heading level0 col4" >tempo</th>
#       <th id="T_e82d5_level0_col5" class="col_heading level0 col5" >duration_ms</th>
#       <th id="T_e82d5_level0_col6" class="col_heading level0 col6" >weeks_on_chart</th>
#       <th id="T_e82d5_level0_col7" class="col_heading level0 col7" >streams</th>
#       <th id="T_e82d5_level0_col8" class="col_heading level0 col8" >mode</th>
#       <th id="T_e82d5_level0_col9" class="col_heading level0 col9" >loudness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e82d5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e82d5_row0_col0" class="data row0 col0" >000xQL6tZNLJzIrtIgxqSl</td>
#       <td id="T_e82d5_row0_col1" class="data row0 col1" >"ZAYN</td>
#       <td id="T_e82d5_row0_col2" class="data row0 col2" > PARTYNEXTDOOR"</td>
#       <td id="T_e82d5_row0_col3" class="data row0 col3" >Still Got Time (feat. PARTYNEXTDOOR)</td>
#       <td id="T_e82d5_row0_col4" class="data row0 col4" >-6.029000</td>
#       <td id="T_e82d5_row0_col5" class="data row0 col5" >120.963000</td>
#       <td id="T_e82d5_row0_col6" class="data row0 col6" >188491.000000</td>
#       <td id="T_e82d5_row0_col7" class="data row0 col7" >17.000000</td>
#       <td id="T_e82d5_row0_col8" class="data row0 col8" >G</td>
#       <td id="T_e82d5_row0_col9" class="data row0 col9" >0.524000</td>
#     </tr>
#     <tr>
#       <th id="T_e82d5_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e82d5_row1_col0" class="data row1 col0" >003eoIwxETJujVWmNFMoZy</td>
#       <td id="T_e82d5_row1_col1" class="data row1 col1" >Alessia Cara</td>
#       <td id="T_e82d5_row1_col2" class="data row1 col2" >Growing Pains</td>
#       <td id="T_e82d5_row1_col3" class="data row1 col3" >Def Jam Recordings</td>
#       <td id="T_e82d5_row1_col4" class="data row1 col4" >191.153000</td>
#       <td id="T_e82d5_row1_col5" class="data row1 col5" >193680.000000</td>
#       <td id="T_e82d5_row1_col6" class="data row1 col6" >2.000000</td>
#       <td id="T_e82d5_row1_col7" class="data row1 col7" >9944865.000000</td>
#       <td id="T_e82d5_row1_col8" class="data row1 col8" >Minor</td>
#       <td id="T_e82d5_row1_col9" class="data row1 col9" >-6.276000</td>
#     </tr>
#     <tr>
#       <th id="T_e82d5_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_
5_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_e82d5_row6_col0" class="data row6 col0" >00ETaeHUQ6lops3oWU1Wrt</td>
#       <td id="T_e82d5_row6_col1" class="data row6 col1" >"Kygo</td>
#       <td

# %% [markdown]
# Pandas compare function (works only for identically-labeled (both index and columns) DataFrame objects)

# %%
table_v4.compare(table_v3)
# Out:
#    artist_names
#            self         other
# 13  Helena Kohl  XXXTENTACION

# %%
table_v4.compare(table_v3, keep_shape = True)
# Out:
#     artist_names       track_name       source       mode       loudness  \
#             self other       self other   self other self other     self
# 0            NaN   NaN        NaN   NaN    NaN   NaN  NaN   NaN      NaN
# 1            NaN   NaN        NaN   NaN    NaN   NaN  NaN   NaN      NaN
# 2            NaN   NaN        NaN   NaN    NaN   NaN  NaN   NaN      NaN
# 3            NaN   NaN        NaN   NaN    NaN   NaN  NaN   NaN      NaN
# 4            NaN   NaN        NaN   NaN    NaN   NaN  NaN   NaN      NaN
# ..           ...   ...        ...   ...    ...   ...  ...   ...      ...
# 988          NaN   NaN        NaN   NaN    NaN   NaN  NaN   NaN      NaN
# 989          NaN   NaN        NaN   NaN    NaN   NaN  NaN   NaN      NaN
# 990          NaN   NaN        NaN   NaN    NaN   NaN  NaN   NaN      NaN
# 991          NaN   NaN        NaN   NaN    NaN   NaN  NaN   NaN      NaN
# 992          NaN   NaN        NaN   NaN    NaN   NaN  NaN   NaN      NaN
#
#           tempo       weeks_on_chart       streams
#     other  self other           self other    self other
# 0     NaN   NaN   NaN            NaN   NaN     NaN   NaN
# 1     NaN   NaN   NaN            NaN   NaN     NaN   NaN
# 2     NaN   NaN   NaN            NaN   NaN     NaN   NaN
# 3     NaN   NaN   NaN            NaN   NaN     NaN   NaN
# 4     NaN   NaN   NaN            NaN   NaN     NaN   NaN
# ..    ...   ...   ...            ...   ...     ...   ...
# 988   NaN   NaN   NaN            NaN   NaN     NaN   NaN
# 989   NaN   NaN   NaN            NaN   NaN     NaN   NaN
# 990   NaN   NaN   NaN            NaN   NaN     NaN   NaN
# 991   NaN   NaN   NaN            NaN   NaN     NaN   NaN
# 992   NaN   NaN   NaN            NaN   NaN     NaN   NaN
#
# [993 rows x 16 columns]

# %%
table_v1.equals(table_v1)
# Out:
# True

# %%
table_v1.equals(table_v3)
# Out:
# False

# %% [markdown]
# Datacompy

# %%
import datacompy

# %%
compare = datacompy.Compare(
    table_v1,
    table_v4,
    join_columns= ('artist_names','track_name', 'source'),  #You can also specify a list of columns
    df1_name='Original', 
    df2_name='New' 
    )
compare.matches(ignore_extra_columns=False)

print(compare.report())
# Out:
# DataComPy Comparison
# --------------------
#
# DataFrame Summary
# -----------------
#
#   DataFrame  Columns  Rows
# 0  Original        8   998
# 1       New        8   993
#
# Column Summary
# --------------
#
# Number of columns in common: 6
# Number of columns in Original but not in New: 2
# Number of columns in New but not in Original: 2
#
# Row Summary
# -----------
#
# Matched on: artist_names, track_name, source
# Any duplicates on match values: Yes
# Absolute Tolerance: 0
# Relative Tolerance: 0
# Number of rows in common: 992
# Number of rows in Original but not in New: 6
# Number of rows in New but not in Original: 1
#
# Number of rows with some compared columns unequal: 0
# Number of rows with all compared columns equal: 992
#
# Column Comparison
# -----------------
#
# Number of columns compared with some values unequal: 0
# Number of columns compared with all values equal: 6
# Total number of values which compare unequal: 0
#
# Sample Rows Only in Original (First 10 Columns)
# -----------------------------------------------
#
#                        id        artist_names            track_name                               source   tempo  duration_ms  weeks_on_chart    streams
# 0  00imgaPlYRrMGn9o83hfmk        Brent Faiyaz          LOOSE CHANGE                      "Lost Kids LLC.  -8.931       84.975      226011.000        1.0
# 1  01TnVDiet1DFTsyWKUKovl        XXXTENTACION                  NUMB                   "Bad Vibes Forever  -8.024      159.910      186268.000       10.0
# 2  00gpGR84M27moP7AFuqHIx          YBN Nahmir  Bounce Out With That                                 2018  94.949    91011.000           6.000  4913180.0
# 3  00ko9WaS4jOX1kEk3gvHjf  "Chance the Rapper             MadeinTYO                              DaBaby"   0.599       -8.040         150.001   225924.0
# 4  00Blm7zeNqgYLPtW6zg8cj        "Post Malone           The Weeknd"      One Right Now (with The Weeknd)  -4.806       97.014      193507.000       30.0
# 5  00B7TZ0Xawar6NZ00JFomN            "Cardi B    Chance the Rapper"  Best Life (feat. Chance The Rapper)  -7.438      167.911      284856.000        2.0
#
# Sample Rows Only in New (First 10 Columns)
# ------------------------------------------
#
#   artist_names track_name              source mode  loudness  tempo  weeks_on_chart  streams
# 0  Helena Kohl       NUMB  "Bad Vibes Forever    B     0.196 -8.024        186268.0     10.0

# %%
compare2 = datacompy.Compare(
    table_v2,
    table_v4,
    join_columns= ('artist_names','track_name', 'source'),  #You can also specify a list of columns
    df1_name='Original', 
    df2_name='New' 
    )
compare2.matches(ignore_extra_columns=False)

print(compare2.report())
# Out:
# DataComPy Comparison
# --------------------
#
# DataFrame Summary
# -----------------
#
#   DataFrame  Columns  Rows
# 0  Original        8   998
# 1       New        8   993
#
# Column Summary
# --------------
#
# Number of columns in common: 8
# Number of columns in Original but not in New: 0
# Number of columns in New but not in Original: 0
#
# Row Summary
# -----------
#
# Matched on: artist_names, track_name, source
# Any duplicates on match values: Yes
# Absolute Tolerance: 0
# Relative Tolerance: 0
# Number of rows in common: 992
# Number of rows in Original but not in New: 6
# Number of rows in New but not in Original: 1
#
# Number of rows with some compared columns unequal: 0
# Number of rows with all compared columns equal: 992
#
# Column Comparison
# -----------------
#
# Number of columns compared with some values unequal: 0
# Number of columns compared with all values equal: 8
# Total number of values which compare unequal: 0
#
# Sample Rows Only in Original (First 10 Columns)
# -----------------------------------------------
#
#          artist_names            track_name                               source               mode  loudness   tempo  weeks_on_chart    streams
# 0        Brent Faiyaz          LOOSE CHANGE                      "Lost Kids LLC.              C#/Db    0.4400  -8.931      226011.000        1.0
# 1            "Cardi B    Chance the Rapper"  Best Life (feat. Chance The Rapper)                  A    0.6650  -7.438      284856.000        2.0
# 2        "Post Malone           The Weeknd"      One Right Now (with The Weeknd)              C#/Db    0.6880  -4.806      193507.000       30.0
# 3          YBN Nahmir  Bounce Out With That                                 2018              Major   -8.2780  94.949           6.000  4913180.0
# 4  "Chance the Rapper             MadeinTYO                              DaBaby"  Chance the Rapper    0.0573   0.599         150.001   225924.0
# 5        XXXTENTACION                  NUMB                   "Bad Vibes Forever                  B    0.1960  -8.024      186268.000       10.0
#
# Sample Rows Only in New (First 10 Columns)
# ------------------------------------------
#
#   artist_names track_name              source mode  loudness  tempo  weeks_on_chart  streams
# 0  Helena Kohl       NUMB  "Bad Vibes Forever    B     0.196 -8.024        186268.0     10.0
